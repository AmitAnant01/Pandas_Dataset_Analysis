# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/welcome/OneDrive/Desktop/googleplaystore.csv')

# %%
print(data)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data[data['Rating'] == data['Rating'].max()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up         NaN

# %%
data[data['Rating'] == data['Rating'].min()]
# Out:
#                                                     App       Category  \
# 625                             House party - live chat         DATING
# 4127                                  Speech Therapy: F         FAMILY
# 5151                                      Clarksburg AH        MEDICAL
# 5978                      Truck Driving Test Class 3 BC         FAMILY
# 6319                   BJ Bridge Standard American 2018           GAME
# 6490                                             MbH BM        MEDICAL
# 7144                                      CB Mobile Biz        FINANCE
# 7383                                     Thistletown CI   PRODUCTIVITY
# 7427                                     CJ DVD Rentals  COMMUNICATION
# 7806                                        CR Magazine       BUSINESS
# 7926                               Tech CU Card Manager        FINANCE
# 8820                                     DS Creator 2.0          TOOLS
# ...

# %%
# To check how many rows and columns present in our dataset
data.shape
# Out:
# (10841, 13)

# %%
print('Number of Rows', data.shape[0])
print('Number of Columns', data.shape[1])
# Out:
# Number of Rows 10841
# Number of Columns 13

# %%
# To get the information about the dataset like Total Number Rows, Total Number of Columns, Datatypes of each column and memory Requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Get the overall statistics of the dataset
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ### In dataset having only Rating Numerical values

# %%
# If i get overall dataset statistics than
data.describe(include = 'all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# Total number of App Title that contains Astrology
data[data['App'].str.contains('Astrology', case = False)]
# Out:
#                                                      App   Category  Rating  \
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5
#
#       Reviews Size     Installs  Type Price Content Rating     Genres  \
# 1570   161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle
# 1592     2225  15M     100,000+  Free     0       Everyone  Lifestyle
# 10840  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle
#
#       Last Updated         Current Ver         Android Ver
# 1570     25-Jun-18          5.2.4(881)        4.0.3 and up
# 1592     26-Jul-18               4.2.1        4.0.3 and up
# 10840    25-Jul-18  Varies with device  Varies with device

# %%
len(data[data['App'].str.contains('Astrology', case  = False)])
# Out:
# 3

# %%
# To find the App rating
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
# Find The Average App Rating
data['Rating'].mean()
# Out:
# 4.193338315362443

# %%
data['Rating'].max()
# Out:
# 19.0

# %%
data['Rating'].min()
# Out:
# 1.0

# %%
# Find The total number of Unique Cotegory
data['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %%
data['Category'].nunique()
# Out:
# 34

# %%
# Which Category has getting the highest rating
data.groupby('Category')['Rating'].mean().sort_values(ascending = False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
# find Total number of apps having 5 star Rating
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Rating'] == 5.0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
data[data['Rating'] == 5]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
len(data[data['Rating'] == 5])
# So this much of category having the 5 star rating
# Out:
# 274

# %%
data[data['Reviews'] =='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up         NaN

# %%
data['Reviews'] =data['Reviews'].replace('3.0M', 3.0)

# %%
data['Reviews'] = data['Reviews'].astype('float')

# %%
data['Reviews'].dtype
# So here the type is Object type
# Out:
# dtype('float64')

# %%
avg_reviews = data['Reviews'].mean()

# %%
print('So this much of the average reviews :',avg_reviews)
# Out:
# So this much of the average reviews : 444111.9265750392

# %%
# To find the no of Free and Paid apps
data['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
# Which app having the highest Reviews
data['Reviews']
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
data['Reviews'].max()
# Out:
# 78158306.0

# %%
data[data['Reviews'].max()== data['Reviews']]
# So this row having the maximum reviews
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
data[data['Reviews'].max() == data['Reviews']]['App']
# So the Facebook App having the heighest Reviews
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
# To Display top 5 Apps that having the heighest Reviews
data['Reviews'].sort_values(ascending = False).head()
# Out:
# 2544    78158306.0
# 3943    78128208.0
# 381     69119316.0
# 336     69119316.0
# 3904    69109672.0
# Name: Reviews, dtype: float64

# %%
# Bottoms reviews
data['Reviews'].sort_values(ascending = False).tail()
# Out:
# 9713    0.0
# 8495    0.0
# 6277    0.0
# 8489    0.0
# 5086    0.0
# Name: Reviews, dtype: float64

# %%
index = data['Reviews'].sort_values(ascending = False).head().index

# %%
data.iloc[index]['App']
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0    159.0  19M   10,000+  Free     0       Everyone
# 1    967.0  14M  500,000+  Free     0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# 0               Art & Design     7-Jan-18       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18       2.0.0  4.0.3 and up

# %%
data.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
# Display top 5 app that having max install
data['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
data['Installs'].dtype
# Out:
# dtype('O')

# %%
data['Installs_1'] = data['Installs'].str.replace(',', '')

# %%
data['Install_1'] = data['Installs_1'].str.replace('+','')

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0    159.0  19M   10,000+  Free     0       Everyone
# 1    967.0  14M  500,000+  Free     0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  \
# 0               Art & Design     7-Jan-18       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18       2.0.0  4.0.3 and up
#
#   Installs_1 Install_1
# 0    10,000+    10,000
# 1   500,000+   500,000

# %%
data[data['Installs'] =='Free']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      3.0
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       Current Ver Android Ver Installs_1 Install_1
# 10472  4.0 and up         NaN          0         0

# %%
data['Installs_1'] = data['Installs_1'].str.replace('free','0')

# %%
data['Installs_1'].dtype
# Out:
# dtype('O')

# %%
index = data['Installs_1'].sort_values(ascending = False).head().index

# %%
data.iloc[index]
# Out:
#                                         App       Category  Rating  \
# 1661                           Temple Run 2           GAME     4.3
# 4039  Google Duo - High Quality Video Calls  COMMUNICATION     4.6
# 385                         Viber Messenger  COMMUNICATION     4.3
# 3562                        Google Calendar   PRODUCTIVITY     4.2
# 4048                                Dropbox   PRODUCTIVITY     4.4
#
#          Reviews                Size      Installs  Type Price Content Rating  \
# 1661   8118609.0                 62M  500,000,000+  Free     0       Everyone
# 4039   2083237.0  Varies with device  500,000,000+  Free     0       Everyone
# 385   11334973.0  Varies with device  500,000,000+  Free     0       Everyone
# 3562    858230.0  Varies with device  500,000,000+  Free     0       Everyone
# 4048   1860844.0                 61M  500,000,000+  Free     0       Everyone
#
#              Genres Last Updated               Current Ver  \
# ...

# %%
data.iloc[index]['App']
# Out:
# 1661                             Temple Run 2
# 4039    Google Duo - High Quality Video Calls
# 385                           Viber Messenger
# 3562                          Google Calendar
# 4048                                  Dropbox
# Name: App, dtype: object
